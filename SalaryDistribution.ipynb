# %%
# %matplotlib nbagg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from sklearn.preprocessing import scale
import seaborn as sns

# %%
train  = pd.read_csv('train.csv')

# %%
salary = (train.Salary).as_matrix()

# %%
plt.close()
plt.xlabel("salary")
plt.ylabel("pdf")
plt.title("Distribution of Salary")
sns.distplot(salary,hist=False,label='probability density of salary')
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.close()
sal = np.log(salary)
plt.xlabel("salary")
plt.ylabel("pdf")
plt.title("Distribution of log - Salary")
sns.distplot(sal,norm_hist=True,hist=True,label='density of log salary')
# Out:
# <img src="data:image/png;base64,...">
